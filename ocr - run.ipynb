# %% [markdown]
# # Setup

# %%
# %reload_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
SYS_PROJECT_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/ocr'
SYS_SRC_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr'
# SYS_CONFIG_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/deoptima/deoptima/deoptima/config'
# SYS_RUNTIME_DIR = '/content/gdrive/MyDrive/Colab Notebooks/deoptima/deoptima/runtime'

# %%
import os
import pandas as pd
import shutil

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.options.mode.copy_on_write = True

# %% [markdown]
# # Download

# %%
# SYS_DOWNLOAD_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr-benchmark'

# %%
# !git clone https://github.com/video-db/ocr-benchmark.git "{SYS_DOWNLOAD_DIR}"

# %% [markdown]
# # Installs

# %%
import os

requirements = """
python-dotenv==1.0.1
imageio==2.37.0
numpy==2.2.2
onnxruntime==1.20.1
openai==1.60.2
opencv-python==4.11.0.86
opencv-python-headless==4.11.0.86
pillow==11.1.0
python-Levenshtein==0.26.1
PyYAML==6.0.2
videodb==0.2.10
grpcio==1.60.1
mistralai==1.5.1
google-genai==1.4.0
"""

requirements_path = os.path.join(SYS_SRC_DIR, 'requirements.txt')
with open(requirements_path, 'w') as f:
    f.write(requirements)
# Out:
# 269

# %%
# !pip install google-genai

# %%
# import locale
# locale.getpreferredencoding = lambda: "UTF-8"

# %%
import os
requirements_path = os.path.join(SYS_SRC_DIR, 'requirements.txt')
# !pip install -q -r '{requirements_path}'
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 84.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 105.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.1/456.1 kB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 123.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 23.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.3 MB/s eta 0:00:00
# ...

# %%
import sys
import os

if SYS_PROJECT_DIR not in sys.path:
    sys.path.append(SYS_PROJECT_DIR)
# Out:
# [autoreload of numpy._core.multiarray failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
# ...

# %%
os.chdir(SYS_SRC_DIR)
from dotenv import load_dotenv
_ = load_dotenv('.env')
from dotenv import dotenv_values
env_from_file = dotenv_values('.env')
# env_from_file

# %% [markdown]
# # GPT-4 - Run

# %%
# !python run.py --model gpt-4o --vid_index 19
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-20 00:37:18,161 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27f-2095-76a3-bc26-96f1167e2526:   0% 0/34 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27f-2095-76a3-bc26-96f1167e2526:   3% 1/34 [00:03<01:59,  3.62s/scene]
# Processing scenes for video m-z-0194c27f-2095-76a3-bc26-96f1167e2526:   6% 2/34 [00:06<01:45,  3.30s/scene]
# Processing scenes for video m-z-0194c27f-2095-76a3-bc26-96f1167e2526:   9% 3/34 [00:09<01:37,  3.16s/scene]
# Processing scenes for video m-z-0194c27f-2095-76a3-bc26-96f1167e2526:  12% 4/34 [00:12<01:34,  3.15s/scene]
# Processing scenes for video m-z-0194c27f-2095-76a3-bc26-96f1167e2526:  15% 5/34 [00:15<01:31,  3.14s/scene]
# ...

# %%
# !python run.py --model gpt-4o --vid_index 20
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-20 00:39:09,683 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27f-60d8-74e2-b777-bfed7d9b49d4:   0% 0/63 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27f-60d8-74e2-b777-bfed7d9b49d4:   2% 1/63 [00:03<03:28,  3.36s/scene]
# Processing scenes for video m-z-0194c27f-60d8-74e2-b777-bfed7d9b49d4:   3% 2/63 [00:05<02:58,  2.92s/scene]
# Processing scenes for video m-z-0194c27f-60d8-74e2-b777-bfed7d9b49d4:   5% 3/63 [00:08<02:46,  2.77s/scene]
# Processing scenes for video m-z-0194c27f-60d8-74e2-b777-bfed7d9b49d4:   6% 4/63 [00:10<02:29,  2.53s/scene]
# Processing scenes for video m-z-0194c27f-60d8-74e2-b777-bfed7d9b49d4:   8% 5/63 [00:13<02:28,  2.55s/scene]
# ...

# %%
# !python run.py --model gpt-4o --vid_index 21
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-20 00:42:05,423 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27f-836c-72f2-8c43-2eeedd6dbc2b:   0% 0/37 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27f-836c-72f2-8c43-2eeedd6dbc2b:   3% 1/37 [00:02<01:44,  2.91s/scene]
# Processing scenes for video m-z-0194c27f-836c-72f2-8c43-2eeedd6dbc2b:   5% 2/37 [00:05<01:42,  2.94s/scene]
# Processing scenes for video m-z-0194c27f-836c-72f2-8c43-2eeedd6dbc2b:   8% 3/37 [00:08<01:38,  2.90s/scene]
# Processing scenes for video m-z-0194c27f-836c-72f2-8c43-2eeedd6dbc2b:  11% 4/37 [00:11<01:36,  2.92s/scene]
# Processing scenes for video m-z-0194c27f-836c-72f2-8c43-2eeedd6dbc2b:  14% 5/37 [00:15<01:39,  3.12s/scene]
# ...

# %%
# !python run.py --model gpt-4o --vid_index 22
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-20 00:48:20,041 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27f-a202-7f00-80a9-3bb8a3bf257d:   0% 0/72 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27f-a202-7f00-80a9-3bb8a3bf257d:   1% 1/72 [00:04<05:03,  4.27s/scene]
# Processing scenes for video m-z-0194c27f-a202-7f00-80a9-3bb8a3bf257d:   3% 2/72 [00:06<03:46,  3.24s/scene]
# Processing scenes for video m-z-0194c27f-a202-7f00-80a9-3bb8a3bf257d:   4% 3/72 [00:08<03:08,  2.73s/scene]
# Processing scenes for video m-z-0194c27f-a202-7f00-80a9-3bb8a3bf257d:   6% 4/72 [00:10<02:47,  2.47s/scene]
# Processing scenes for video m-z-0194c27f-a202-7f00-80a9-3bb8a3bf257d:   7% 5/72 [00:16<04:03,  3.64s/scene]
# ...

# %%
# !python run.py --model gpt-4o --vid_index 23
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-20 00:51:32,348 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27f-e828-7f43-be2e-7fa19bc39dd4:   0% 0/102 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27f-e828-7f43-be2e-7fa19bc39dd4:   1% 1/102 [00:04<07:14,  4.30s/scene]
# Processing scenes for video m-z-0194c27f-e828-7f43-be2e-7fa19bc39dd4:   2% 2/102 [00:07<06:28,  3.88s/scene]
# Processing scenes for video m-z-0194c27f-e828-7f43-be2e-7fa19bc39dd4:   3% 3/102 [00:11<06:02,  3.66s/scene]
# Processing scenes for video m-z-0194c27f-e828-7f43-be2e-7fa19bc39dd4:   4% 4/102 [00:14<05:49,  3.57s/scene]
# Processing scenes for video m-z-0194c27f-e828-7f43-be2e-7fa19bc39dd4:   5% 5/102 [00:17<05:34,  3.45s/scene]
# ...

# %%
# !python run.py --model gpt-4o --vid_index 24
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-20 01:08:51,330 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c280-0778-7b52-8268-c6f1d00dbd52:   0% 0/83 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c280-0778-7b52-8268-c6f1d00dbd52:   1% 1/83 [00:03<04:26,  3.25s/scene]
# Processing scenes for video m-z-0194c280-0778-7b52-8268-c6f1d00dbd52:   2% 2/83 [00:06<04:21,  3.23s/scene]
# Processing scenes for video m-z-0194c280-0778-7b52-8268-c6f1d00dbd52:   4% 3/83 [00:09<04:09,  3.11s/scene]
# Processing scenes for video m-z-0194c280-0778-7b52-8268-c6f1d00dbd52:   5% 4/83 [00:12<04:00,  3.05s/scene]
# Processing scenes for video m-z-0194c280-0778-7b52-8268-c6f1d00dbd52:   6% 5/83 [00:15<04:05,  3.14s/scene]
# ...

# %% [markdown]
# # Mistral - Sample Run

# %%
# image_url = "https://storage.videodb.io/media/u-0e58db00-6548-4d3c-b8c1-4ddddc072787/m-z-0194c270-bbfb-7dd2-aaec-62d909b97b32/frames/frm-scn-tt1sff1-3.0-4.0-3.5/img-6f09a960-1078-4fb6-8b50-3edc6391aa56.png"

# %%
# import os
# from mistralai import Mistral

# api_key = os.environ["MISTRAL_API_KEY"]
# client = Mistral(api_key=api_key)

# ocr_response = client.ocr.process(
#     model="mistral-ocr-latest",
#     document={
#         "type": "image_url",
#         "image_url": image_url
#     }
# )

# %%
# ocr_response.pages[0].markdown
# Out:
# [OCRPageObject(index=0, markdown='# HOW TO READ A CASE* \n\n## And Understand What it Means\n\n"What is reading but silent conversation?"\n\n- Walter Savage Landor\n\n[^0]\n[^0]:    * Based in part on article by Julie Novkov at University at Albany, SUNY', images=[], dimensions=OCRPageDimensions(dpi=200, height=720, width=960))]

# %% [markdown]
# # Mistral - Run

# %%
# !python run.py --model mistral --vid_index 4
# Out:
# Directory already exists: ocr_results/mistral_results/mistral-ocr-latest
# 2025-03-10 00:41:54,255 ################################ Running mistral-ocr-latest Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:   0% 0/29 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:   3% 1/29 [00:03<01:40,  3.58s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:   7% 2/29 [00:06<01:27,  3.23s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  10% 3/29 [00:09<01:20,  3.12s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  14% 4/29 [00:12<01:18,  3.12s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  17% 5/29 [00:16<01:19,  3.30s/scene]
# ...

# %% [markdown]
# # Gemini 2.0 Flash - Run

# %%
# !python run_1.py --model gemini-2.0-flash --vid_index 3 --generate_images

# %%
# !python run.py --model gemini-2.0-flash --vid_index 3
# Out:
# Directory already exists: ocr_results/gemini_results/gemini-2.0-flash
# 2025-03-18 22:36:03,027 ################################ Running gemini-2.0-flash Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   0% 0/36 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   3% 1/36 [00:01<00:38,  1.09s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   6% 2/36 [00:02<00:46,  1.37s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   8% 3/36 [00:04<00:59,  1.80s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  11% 4/36 [00:07<01:09,  2.17s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  14% 5/36 [00:10<01:16,  2.46s/scene]
# ...

# %% [markdown]
# # Sleep

# %%
# import time
# time.sleep(30000)
