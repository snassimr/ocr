# %% [markdown]
# # Setup

# %%
# %reload_ext autoreload
# %autoreload 2

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount = True)
# Out:
# Mounted at /content/gdrive

# %%
SYS_PROJECT_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/ocr'
SYS_SRC_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr'
# SYS_CONFIG_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/deoptima/deoptima/deoptima/config'
# SYS_RUNTIME_DIR = '/content/gdrive/MyDrive/Colab Notebooks/deoptima/deoptima/runtime'

# %%
import os
import pandas as pd
import shutil

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.options.mode.copy_on_write = True

# %% [markdown]
# # Download

# %%
# SYS_DOWNLOAD_DIR  = '/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr-benchmark'

# %%
# !git clone https://github.com/video-db/ocr-benchmark.git "{SYS_DOWNLOAD_DIR}"

# %% [markdown]
# # Installs

# %%
import os

requirements = """
python-dotenv==1.0.1
imageio==2.37.0
numpy==2.2.2
onnxruntime==1.20.1
openai==1.60.2
opencv-python==4.11.0.86
opencv-python-headless==4.11.0.86
pillow==11.1.0
python-Levenshtein==0.26.1
PyYAML==6.0.2
videodb==0.2.10
grpcio==1.60.1
mistralai==1.5.1
google-genai==1.4.0
"""

requirements_path = os.path.join(SYS_SRC_DIR, 'requirements.txt')
with open(requirements_path, 'w') as f:
    f.write(requirements)
# Out:
# 269

# %%
# !pip install google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.38.0)
# Requirement already satisfied: httpx<1.0.0dev,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0dev,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.10.6)
# Requirement already satisfied: requests<3.0.0dev,>=2.28.1 in /usr/local/lib/python3.11/dist-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.0dev,>=13.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (14.2)
# Requirement already satisfied: typing-extensions<5.0.0dev,>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from google-genai) (4.12.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-genai) (4.9)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0dev,>=0.28.1->google-genai) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0dev,>=0.28.1->google-genai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0dev,>=0.28.1->google-genai) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<1.0.0dev,>=0.28.1->google-genai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1.0.0dev,>=0.28.1->google-genai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0dev,>=2.0.0->google-genai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.28.1->google-genai) (2.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-genai) (0.6.1)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1.0.0dev,>=0.28.1->google-genai) (1.3.1)

# %%
# import locale
# locale.getpreferredencoding = lambda: "UTF-8"

# %%
import os
requirements_path = os.path.join(SYS_SRC_DIR, 'requirements.txt')
# !pip install -q -r '{requirements_path}'
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 68.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 58.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 456.1/456.1 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.7/162.7 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.2 MB/s eta 0:00:00
#   Building wheel for videodb (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.2 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.2.2 which is incompatible.
# grpcio-status 1.62.3 requires grpcio>=1.62.3, but you have grpcio 1.60.1 which is incompatible.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.2.2 which is incompatible.

# %%
import sys
import os

if SYS_PROJECT_DIR not in sys.path:
    sys.path.append(SYS_PROJECT_DIR)
# Out:
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/multiarray.py", line 1, in <module>
#     from numpy._core import multiarray
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 93, in _override___module__
#     ufunc.__module__ = "numpy"
#     ^^^^^^^^^^^^^^^^
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.core.fromnumeric failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/usr/local/lib/python3.11/dist-packages/numpy/core/_multiarray_umath.cpython-311-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.core.numeric failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/usr/local/lib/python3.11/dist-packages/numpy/core/_multiarray_umath.cpython-311-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.core._internal failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/_internal.py", line 1, in <module>
#     from numpy._core import _internal
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/_internal.py", line 14, in <module>
#     from .multiarray import dtype, array, ndarray, promote_types, StringDType
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.core failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/usr/local/lib/python3.11/dist-packages/numpy/core/_multiarray_umath.cpython-311-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.lib.mixins failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/usr/local/lib/python3.11/dist-packages/numpy/core/_multiarray_umath.cpython-311-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.lib.scimath failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/scimath.py", line 1, in <module>
#     from ._scimath_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_scimath_impl.py", line 17, in <module>
#     import numpy._core.numeric as nx
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.lib.stride_tricks failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/stride_tricks.py", line 1, in <module>
#     from ._stride_tricks_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_stride_tricks_impl.py", line 8, in <module>
#     from numpy._core.numeric import normalize_axis_tuple
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# /usr/local/lib/python3.11/dist-packages/numpy/_typing/_scalars.py:12: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   _BoolLike_co: TypeAlias = bool | np.bool
# [autoreload of numpy._typing._scalars failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_typing/_scalars.py", line 12, in <module>
#     _BoolLike_co: TypeAlias = bool | np.bool
#                                      ^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/__init__.py", line 324, in __getattr__
#     warnings.filterwarnings("ignore", message="numpy.ndarray size changed")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ]
# /usr/local/lib/python3.11/dist-packages/numpy/_typing/_dtype_like.py:141: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   | type[np.bool]
# [autoreload of numpy._typing._dtype_like failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_typing/_dtype_like.py", line 141, in <module>
#     | type[np.bool]
#            ^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/__init__.py", line 324, in __getattr__
#     warnings.filterwarnings("ignore", message="numpy.ndarray size changed")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'numpy' has no attribute 'bool'.
# `np.bool` was a deprecated alias for the builtin `bool`. To avoid this error in existing code, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ]
# [autoreload of numpy._typing._array_like failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_typing/_array_like.py", line 33, in <module>
#     from numpy._core.multiarray import StringDType
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 93, in _override___module__
#     ufunc.__module__ = "numpy"
#     ^^^^^^^^^^^^^^^^
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy._typing failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_typing/__init__.py", line 120, in <module>
#     from ._array_like import (
# ImportError: cannot import name '_ArrayLikeFloat64_co' from 'numpy._typing._array_like' (/usr/local/lib/python3.11/dist-packages/numpy/_typing/_array_like.py)
# ]
# [autoreload of numpy.linalg failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/linalg/linalg.py", line 3, in __getattr__
#     from numpy.linalg import _linalg
#   File "/usr/local/lib/python3.11/dist-packages/numpy/linalg/_linalg.py", line 25, in <module>
#     from numpy._core import (
# ImportError: cannot import name 'array' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.matrixlib.defmatrix failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/matrixlib/defmatrix.py", line 8, in <module>
#     import numpy._core.numeric as N
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.lib.format failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/format.py", line 170, in <module>
#     from numpy.lib._utils_impl import drop_metadata
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_utils_impl.py", line 9, in <module>
#     from numpy._core import ndarray
# ImportError: cannot import name 'ndarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.lib._iotools failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_iotools.py", line 7, in <module>
#     import numpy._core.numeric as nx
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.lib.npyio failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py", line 1, in <module>
#     from ._npyio_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_npyio_impl.py", line 20, in <module>
#     from numpy._core.multiarray import packbits, unpackbits
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/__init__.py", line 13, in <module>
#     from . import array_utils
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.fft._pocketfft failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/fft/_pocketfft.py", line 36, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.fft failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/fft/helper.py", line 3, in __getattr__
#     from numpy.fft import _helper
#   File "/usr/local/lib/python3.11/dist-packages/numpy/fft/_helper.py", line 5, in <module>
#     from numpy._core import integer, empty, arange, asarray, roll
# ImportError: cannot import name 'integer' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.polyutils failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/polyutils.py", line 27, in <module>
#     from numpy._core.multiarray import dragon4_positional, dragon4_scientific
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 93, in _override___module__
#     ufunc.__module__ = "numpy"
#     ^^^^^^^^^^^^^^^^
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.polynomial.polynomial failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/polynomial.py", line 85, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.chebyshev failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/chebyshev.py", line 112, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.legendre failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/legendre.py", line 84, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.hermite failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/hermite.py", line 80, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.hermite_e failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/hermite_e.py", line 80, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.polynomial.laguerre failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/polynomial/laguerre.py", line 80, in <module>
#     from numpy.lib.array_utils import normalize_axis_index
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy.ctypeslib failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/ctypeslib.py", line 57, in <module>
#     from numpy._core.multiarray import _flagdict, flagsobj
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 93, in _override___module__
#     ufunc.__module__ = "numpy"
#     ^^^^^^^^^^^^^^^^
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 374, in superreload
#     if not hasattr(obj, '__module__') or obj.__module__ != module.__name__:
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/numpy/core/umath.py", line 2, in __getattr__
#     from numpy._core import umath
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/umath.py", line 15, in <module>
#     from ._multiarray_umath import (
# ImportError: cannot import name '_get_extobj_dict' from 'numpy.core._multiarray_umath' (/usr/local/lib/python3.11/dist-packages/numpy/core/_multiarray_umath.cpython-311-x86_64-linux-gnu.so)
# ]
# [autoreload of numpy.ma.extras failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/ma/extras.py", line 35, in <module>
#     from numpy.lib.array_utils import normalize_axis_index, normalize_axis_tuple
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/array_utils.py", line 1, in <module>
#     from ._array_utils_impl import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/lib/_array_utils_impl.py", line 4, in <module>
#     from numpy._core import asarray
# ImportError: cannot import name 'asarray' from 'numpy._core' (/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py)
# ]
# [autoreload of numpy failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/__init__.py", line 122, in <module>
#     from ._core import (
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/memmap.py", line 5, in <module>
#     from .numeric import uint8, ndarray, dtype
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/numeric.py", line 11, in <module>
#     from . import multiarray
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]
# [autoreload of numpy._core failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/imp.py", line 315, in reload
#     return importlib.reload(module)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 940, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/__init__.py", line 23, in <module>
#     from . import multiarray
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 97, in <module>
#     _override___module__()
#   File "/usr/local/lib/python3.11/dist-packages/numpy/_core/multiarray.py", line 93, in _override___module__
#     ufunc.__module__ = "numpy"
#     ^^^^^^^^^^^^^^^^
# AttributeError: 'numpy.ufunc' object has no attribute '__module__'
# ]

# %%
os.chdir(SYS_SRC_DIR)
from dotenv import load_dotenv
_ = load_dotenv('.env')
from dotenv import dotenv_values
env_from_file = dotenv_values('.env')
env_from_file

# %% [markdown]
# # GPT-4 - Run

# %%
# !python run.py --model gpt-4o --vid_index 3
# Out:
# Directory already exists: ocr_results/gpt_results/gpt-4o
# 2025-03-10 02:06:01,812 ################################ Running gpt-4o Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   0% 0/36 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   3% 1/36 [00:03<02:11,  3.74s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   6% 2/36 [00:05<01:36,  2.82s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:   8% 3/36 [00:08<01:33,  2.84s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  11% 4/36 [00:12<01:42,  3.21s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  14% 5/36 [00:16<01:47,  3.48s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  17% 6/36 [00:20<01:47,  3.60s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  19% 7/36 [00:23<01:44,  3.59s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  22% 8/36 [00:27<01:37,  3.50s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  25% 9/36 [00:32<01:50,  4.10s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  28% 10/36 [00:39<02:04,  4.81s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  31% 11/36 [00:47<02:27,  5.90s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  33% 12/36 [00:50<02:00,  5.04s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  36% 13/36 [00:54<01:51,  4.87s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  39% 14/36 [00:58<01:40,  4.57s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  42% 15/36 [01:02<01:31,  4.35s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  44% 16/36 [01:05<01:17,  3.86s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  47% 17/36 [01:08<01:09,  3.68s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  50% 18/36 [01:11<01:01,  3.39s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  53% 19/36 [01:14<00:53,  3.17s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  56% 20/36 [01:16<00:47,  3.00s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  58% 21/36 [01:21<00:51,  3.45s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  61% 22/36 [01:27<01:00,  4.30s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  64% 23/36 [01:30<00:51,  3.98s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  67% 24/36 [01:33<00:43,  3.62s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  69% 25/36 [01:37<00:41,  3.78s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  72% 26/36 [01:40<00:35,  3.58s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  75% 27/36 [01:44<00:32,  3.58s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  78% 28/36 [01:46<00:25,  3.22s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  81% 29/36 [01:49<00:20,  2.97s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  83% 30/36 [01:51<00:16,  2.81s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  86% 31/36 [01:54<00:13,  2.79s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  89% 32/36 [01:57<00:11,  2.96s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  92% 33/36 [02:00<00:08,  2.83s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  94% 34/36 [02:01<00:04,  2.33s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6:  97% 35/36 [02:02<00:01,  1.99s/scene]
# Processing scenes for video m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6: 100% 36/36 [02:03<00:00,  3.43s/scene]
# 2025-03-10 02:08:06,462 model results of m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6 saved to ocr_results/gpt_results/gpt-4o/ocr_2025-03-10_02-06-01/m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6_output.json
# 2025-03-10 02:08:06,477 results evaluations of m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6 saved to ocr_results/gpt_results/gpt-4o/ocr_2025-03-10_02-06-01/evaluations/m-z-0194c27c-aebe-75d0-812f-06fbeb60b7d6.json
# Processing videos: 100% 1/1 [02:04<00:00, 124.66s/video]
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr/run.py", line 175, in <module>
#     main(args)
#   File "/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr/run.py", line 166, in main
#     save_summary(current_run)
#   File "/content/gdrive/MyDrive/Colab Notebooks/ocr/ocr/utils.py", line 146, in save_summary
#     for model in os.listdir(os.path.join("ocr_results",model_result)):
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# NotADirectoryError: [Errno 20] Not a directory: 'ocr_results/summary_data_mistral-ocr-latest.json'

# %% [markdown]
# # Mistral - Sample Run

# %%
# image_url = "https://storage.videodb.io/media/u-0e58db00-6548-4d3c-b8c1-4ddddc072787/m-z-0194c270-bbfb-7dd2-aaec-62d909b97b32/frames/frm-scn-tt1sff1-3.0-4.0-3.5/img-6f09a960-1078-4fb6-8b50-3edc6391aa56.png"

# %%
# import os
# from mistralai import Mistral

# api_key = os.environ["MISTRAL_API_KEY"]
# client = Mistral(api_key=api_key)

# ocr_response = client.ocr.process(
#     model="mistral-ocr-latest",
#     document={
#         "type": "image_url",
#         "image_url": image_url
#     }
# )

# %%
# ocr_response.pages[0].markdown
# Out:
# [OCRPageObject(index=0, markdown='# HOW TO READ A CASE* \n\n## And Understand What it Means\n\n"What is reading but silent conversation?"\n\n- Walter Savage Landor\n\n[^0]\n[^0]:    * Based in part on article by Julie Novkov at University at Albany, SUNY', images=[], dimensions=OCRPageDimensions(dpi=200, height=720, width=960))]

# %% [markdown]
# # Mistral - Run

# %%
# !python run.py --model mistral --vid_index 4
# Out:
# Directory already exists: ocr_results/mistral_results/mistral-ocr-latest
# 2025-03-10 00:41:54,255 ################################ Running mistral-ocr-latest Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:   0% 0/29 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:   3% 1/29 [00:03<01:40,  3.58s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:   7% 2/29 [00:06<01:27,  3.23s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  10% 3/29 [00:09<01:20,  3.12s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  14% 4/29 [00:12<01:18,  3.12s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  17% 5/29 [00:16<01:19,  3.30s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  21% 6/29 [00:19<01:13,  3.21s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  24% 7/29 [00:22<01:12,  3.27s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  28% 8/29 [00:26<01:09,  3.29s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  31% 9/29 [00:29<01:05,  3.28s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  34% 10/29 [00:32<01:02,  3.30s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  38% 11/29 [00:36<01:00,  3.33s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  41% 12/29 [00:39<00:54,  3.23s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  45% 13/29 [00:42<00:51,  3.22s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  48% 14/29 [00:45<00:49,  3.33s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  52% 15/29 [00:49<00:49,  3.50s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  55% 16/29 [00:53<00:45,  3.48s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  59% 17/29 [00:56<00:41,  3.48s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  62% 18/29 [00:59<00:37,  3.41s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  66% 19/29 [01:03<00:33,  3.35s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  69% 20/29 [01:06<00:29,  3.28s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  72% 21/29 [01:09<00:26,  3.37s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  76% 22/29 [01:13<00:23,  3.36s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  79% 23/29 [01:16<00:20,  3.36s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  83% 24/29 [01:19<00:16,  3.39s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  86% 25/29 [01:23<00:13,  3.47s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  90% 26/29 [01:26<00:10,  3.37s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  93% 27/29 [01:29<00:06,  3.25s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a:  97% 28/29 [01:32<00:03,  3.19s/scene]
# Processing scenes for video m-z-0194c27c-d107-7030-b990-0b5cc62f514a: 100% 29/29 [01:35<00:00,  3.31s/scene]
# 2025-03-10 00:43:31,160 model results of m-z-0194c27c-d107-7030-b990-0b5cc62f514a saved to ocr_results/mistral_results/mistral-ocr-latest/ocr_2025-03-10_00-41-53/m-z-0194c27c-d107-7030-b990-0b5cc62f514a_output.json
# 2025-03-10 00:43:31,408 results evaluations of m-z-0194c27c-d107-7030-b990-0b5cc62f514a saved to ocr_results/mistral_results/mistral-ocr-latest/ocr_2025-03-10_00-41-53/evaluations/m-z-0194c27c-d107-7030-b990-0b5cc62f514a.json
# Processing videos: 100% 1/1 [01:37<00:00, 97.15s/video]

# %% [markdown]
# # Gemini 2.0 Flash - Run

# %%
# !python run.py --model gemini-2.0-flash --vid_index 5
# Out:
# Directory already exists: ocr_results/gemini_results/gemini-2.0-flash
# 2025-03-17 01:02:33,116 ################################ Running gemini-2.0-flash Model on OCR Prompt ################################
#
# Processing videos:   0% 0/1 [00:00<?, ?video/s]Found existing scene collection: tt1sff1
#
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:   0% 0/32 [00:00<?, ?scene/s]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:   3% 1/32 [00:02<01:04,  2.08s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:   6% 2/32 [00:03<00:59,  1.98s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:   9% 3/32 [00:05<00:55,  1.92s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  12% 4/32 [00:07<00:52,  1.87s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  16% 5/32 [00:09<00:49,  1.83s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  19% 6/32 [00:11<00:47,  1.84s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  22% 7/32 [00:13<00:47,  1.90s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  25% 8/32 [00:15<00:45,  1.88s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  28% 9/32 [00:16<00:43,  1.88s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  31% 10/32 [00:18<00:41,  1.90s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  34% 11/32 [00:20<00:39,  1.88s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  38% 12/32 [00:22<00:38,  1.94s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  41% 13/32 [00:24<00:37,  1.95s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  44% 14/32 [00:26<00:35,  1.97s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  47% 15/32 [00:28<00:33,  1.95s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  50% 16/32 [00:30<00:31,  1.95s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  53% 17/32 [00:32<00:29,  1.95s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  56% 18/32 [00:34<00:26,  1.92s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  59% 19/32 [00:36<00:25,  1.96s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  62% 20/32 [00:38<00:23,  1.97s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  66% 21/32 [00:40<00:21,  1.97s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  69% 22/32 [00:42<00:19,  1.99s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  72% 23/32 [00:46<00:22,  2.47s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  75% 24/32 [00:49<00:22,  2.84s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  78% 25/32 [00:53<00:21,  3.04s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  81% 26/32 [00:57<00:19,  3.23s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  84% 27/32 [01:00<00:16,  3.34s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  88% 28/32 [01:02<00:11,  2.94s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  91% 29/32 [01:04<00:07,  2.58s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  94% 30/32 [01:06<00:04,  2.30s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2:  97% 31/32 [01:07<00:02,  2.07s/scene]
# Processing scenes for video m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2: 100% 32/32 [01:09<00:00,  2.18s/scene]
# 2025-03-17 01:03:44,099 model results of m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2 saved to ocr_results/gemini_results/gemini-2.0-flash/ocr_2025-03-17_01-02-32/m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2_output.json
# 2025-03-17 01:03:44,423 results evaluations of m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2 saved to ocr_results/gemini_results/gemini-2.0-flash/ocr_2025-03-17_01-02-32/evaluations/m-z-0194c27c-f30c-7803-b2ca-8f1026c940a2.json
# Processing videos: 100% 1/1 [01:11<00:00, 71.30s/video]

# %% [markdown]
# # Sleep

# %%
# import time
# time.sleep(30000)
